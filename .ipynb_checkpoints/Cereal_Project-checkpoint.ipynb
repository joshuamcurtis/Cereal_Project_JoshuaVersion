# %% [markdown]
# # Econ 1923 - Product Differentiation Project

# %% [markdown]
# ## 1 Preparation
# ### 1.1 Obtaining the data
# Create a data set containing nutrition information about cereal boxes. You can use all sources including the nutrition APIs, stores web pages, actual grocery stores, your pantry, etc.
# At the end of this process, you should have a dataframe that contains as many cereal boxes as possible and for each, you should have several nutritional facts and (ideally) serving sizes (cups or grams).
# The result of this part can be several dataframes, each resulting from the different data sources that you used.
#
# Sources: Edemam API, GitHub JSON Files, personal cereals

# %%
#Importing packages
import requests, json, time
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
# %run ../APIkeys.py

# %%
app_id = os.environ['EDAMAM_API_id']
key = os.environ['EDAMAM_API_key']
#baseURL = 'https://api.edamam.com/api/food-database/v2/parser?app_id='+app_id+'&app_key='+key+'&upc='
#endURL = '&nutrition-type=cooking&category=packaged-foods'

pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
def checkUPC_edamam(upc):
    # This function is called checkUPC_V2 in previous notebooks
    
    edamam_id = os.environ['EDAMAM_API_id']
    edamam_key = os.environ['EDAMAM_API_key']
    edamam_baseURL = 'https://api.edamam.com/api/food-database/v2/parser?app_id='+edamam_id+'&app_key='+edamam_key+'&upc='
    edamam_endURL = '&nutrition-type=cooking&category=packaged-foods'
    url = edamam_baseURL + upc + edamam_endURL
    info = requests.get(url).json()
    if 'error' in info:
        return info
    else:
        answer = info['hints'][0]['food']['nutrients']
        
        sizeList = info['hints'][0]['food']['servingSizes']
        n = len(sizeList)
        for i in range(n):
            if sizeList[i]['label'] == 'Gram':
                answer['servingSize_gram'] = info['hints'][0]['food']['servingSizes'][i]['quantity']
            if sizeList[i]['label'] == 'Cup':
                answer['servingSize_cup'] = info['hints'][0]['food']['servingSizes'][i]['quantity']
        
        answer['label'] = info['hints'][0]['food']['label']
        answer['upc'] = upc
        return answer

# %%
#We add a 2 second interval between each call to stay under the limit for the Edamam API.

def multiUPC_edamam(shelf, verbose = False, leftovers = False, source=""):
    # This function is called multiUPC_V2 in previous notebooks
    
    # Shelf - a list of strings, each representing a UPC code
    # verbose - boolean telling the function whether to print found/unfound UPCs
    # leftovers - boolean telling the function whetehr to output the 
    
    found = []    #container for information on found UPCS
    unfound = []  #container for unfound UPCs
    
    # loop over UPCs in shelf
    for upc in shelf:
        info = checkUPC_edamam(upc)
        
        if 'error' in info:
            unfound.append(upc) #add to the unfound container
            if verbose:
                print('UPC ',upc, ' does not exist in the API\'s data base')
                time.sleep(2)
        
        else:
            if verbose:
                print('UPC ',upc, ' exists in the API\'s data base')
                time.sleep(2)
            found.append(info)
    
    # turn the dictionary found into a Dataframe
    if len(found)>0:
        df_found = pd.DataFrame(found)
    else:
        df_found = pd.DataFrame()
    
    # add a source column
    df_found["dataSource"] = pd.Series([source for i in range(len(df_found.index))])
    
    
    # return the values of found and unfound (optional)
    if leftovers:
        return df_found,unfound
    else:
        return df_found

# %%
#Get Whole Foods / Giant Eagle Cereals
url = "https://raw.githubusercontent.com/ArieBeresteanu/Econ-1923/main/Cereal_Project/cereal_WholeFoods.json"
response = json.loads(requests.get(url).text)

# skipping the first entry
WF_GE_DF = pd.DataFrame(response['cereal'])

# Getting the shape of the dataframe:
# n = number of rows (observations)
# c = number of columns
n,c = WF_GE_DF.shape

# names of columns
#WF_GE_DF.columns

# %%
# Save raw whole foods data to excel
WF_GE_DF.to_excel("WholeFoods_GiantEagle_Raw.xlsx", sheet_name='Cereal Data')

# %%
# rename columns
WF_GE_DF = WF_GE_DF.rename(columns={"ENERC_KCAL": "CALORIES", 
                                "Carb": "CARB", 
                                "Protein": "PROTEIN", 
                                "Iron": "IRON", 
                                "Calcium": "CALCIUM", 
                                "Fiber": "FIBER",
                                "VitB6A": "VITB6A",
                                "FAMONO": "FATMONO",
                                "servingSize_Gram": "servingSize_gram"
                             })
WF_GE_DF['dataSource'] = 'GiantEagle / WholeFoods'
WF_GE_DF
# Out:
#                                                 label  CALORIES   FAT  FASAT  \
# 0   Purely Elizabeth, Original Ancient Grain Grano...       130   6.0    3.5
# 1        Catalina Crunch, Cinnamon Toast Cereal, 9 oz       110   5.0    0.5
# 2        Catalina Crunch, Dark Chocolate Cereal, 9 oz       110   6.0    1.0
# 3         Michele's Granola,  Original Granola, 12 oz       150   9.0    2.0
# 4   365 by Whole Foods Market, Organic Cereal, Oat...       240   7.0    0.5
# 5   Nature's Path Organic, Heritage Flakes Cereal,...       160   1.5    0.0
# 6                        Cheerios Honey Nut , 15.4 oz       180   2.0    0.0
# 7   Nature's Path Organic, Heritage Flakes Cereal,...       160   1.5    0.0
# 8   Cascadian Farm, Organic Cinnamon Crunch Cereal...       180   3.0    0.0
# 9   365 by Whole Foods Market, Granola Maple Almon...       260   9.0    1.0
# 10  365 by Whole Foods Market, Raisin Bran Cereal,...       170   1.0    0.0
# 11  Purely Elizabeth. Blueberry Hemp Ancient Grain...       130   5.0    NaN
# 12  KIND Snacks, Peanut Butter Whole Grain Cluster...       120   4.0    0.5
# 13  KIND Snacks, Kind Healthy Grains Oats & Honey ...       110   2.5    5.0
# 14          Main Street, Chunky Granola With Flaxseed       250  11.0    1.0
# 15    Bob's Red Mill, Old Country Style Muesli, 40 oz       140   3.0    0.0
# 16  365 by Whole Foods Market, Organic Morning O's...       150   2.5    0.0
# 17  Nature's Path Organic, Organic Heritage Flakes...       200   1.5    0.0
# 18  365 by Whole Foods Market, Organic Cereal Hone...       150   1.5    0.0
# 19  365 by Whole Foods Market, Organic Cereal, Fre...       270   8.0    1.0
# 20       Kashi. Go Lean Peanut Butter Crunch, 13.2 oz       220   9.0    1.0
# 21  Nature's Path Organic, Mesa Sunrise Cereal, Fa...       160   1.5    1.0
# 22  Nature's Path Organic. Dark Chocolate & Red Be...       130   5.0    1.0
# 23   Nature's Path Organic, Panda Puffs Cereal, 10 oz       170   4.5    1.5
# 24         Michele's Granola, Cinnamon Raisin , 12 oz       140   8.0    2.0
# 25  Catalina Crunch, Keto Friendly Fruity Cereal, ...       110   5.0    0.5
# 26  Annie's Homegrown, Organic Cocoa Bunnies Oat, ...       140   2.0    0.5
# 27  Kashi, Heart To Heart Organic Blueberry Cluste...       200   2.5    0.5
# 58     NaN  NaN   NaN  GiantEagle / WholeFoods
# 59     NaN  NaN   NaN  GiantEagle / WholeFoods
# 60     NaN  NaN   NaN  GiantEagle / WholeFoods
# 61     NaN  NaN   NaN  GiantEagle / WholeFoods
# 62     NaN  NaN   NaN  GiantEagle / WholeFoods
# 63     NaN  NaN   NaN  GiantEagle / WholeFoods
# 64     NaN  NaN   NaN  GiantEagle / WholeFoods
# 65     NaN  NaN   NaN  GiantEagle / WholeFoods
# 66     NaN  NaN   NaN  GiantEagle / WholeFoods
# 67     NaN  NaN   NaN  GiantEagle / WholeFoods
# 68     NaN  NaN   NaN  GiantEagle / WholeFoods
# 69     NaN  NaN   NaN  GiantEagle / WholeFoods
# 70     NaN  NaN   NaN  GiantEagle / WholeFoods
# 71     NaN  NaN   NaN  GiantEagle / WholeFoods
# 72     NaN  NaN   NaN  GiantEagle / WholeFoods
# 73     NaN  NaN   NaN  GiantEagle / WholeFoods
# 74     NaN  NaN   NaN  GiantEagle / WholeFoods

# %%
#reading excel and csv files containing states' WIC 
#Approved Products Lists (APLs) and filtering down to cereal UPCs

df_IL = pd.read_excel('IL_WIC_APL.xlsx') #Illinois
df_IL = df_IL.drop([174], axis=0)
df_IL = df_IL.reset_index(drop=True)

df_MA = pd.read_excel('MA_WIC_APL.xlsx')
df_MA = df_MA[df_MA['Category Name']=='Breakfast Cereal'] #Massachusetts
df_MA = df_MA.reset_index(drop=True)

df_MN = pd.read_excel('MN_WIC_APL.xlsx')#Minnesota

df_NE = pd.read_excel('NE_WIC_APL.xlsx')#Nebraska

df_NV = pd.read_csv('NV_WIC_APL.csv')#Nevada

df_NY = pd.read_excel('NY_WIC_APL.xlsx')#New York S
df_NY = df_NY[df_NY['Category']=='Breakfast Cereal ']
df_NY = df_NY.reset_index(drop=True)

# %%
#Isolating UPCs into string arrays and combining
IL_UPCs = []
for i in range(0,len(df_IL['UPC/PLU Code'])-1):
    IL_UPCs.append(df_IL['UPC/PLU Code'][i][7:18])
    
MA_UPCs = []
for i in range(0,len(df_MA['UPC'])-1):
    MA_UPCs.append(str(df_MA['UPC'][i]))

MN_UPCs = []
for i in range(0,len(df_MN['UPC_PLU'])-1):
    MN_UPCs.append(str(df_MN['UPC_PLU'][i]))
    
NE_UPCs = []
for i in range(0,len(df_NE['UPC'])-1):
    NE_UPCs.append(str(df_NE['UPC'][i]))

NV_UPCs = []
for i in range(0,len(df_NV['UPC'])-1):
    if len(df_NV['UPC'][i])==14:
        NV_UPCs.append(df_NV['UPC'][i][2:13])
    elif len(df_NV['UPC'][i])==15:
        NV_UPCs.append(df_NV['UPC'][i][3:14])

NY_UPCs = []
for i in range(0,len(df_NY['UPC/PLU Number'])-1):
    if len(str(df_NY['UPC/PLU Number'][i]))==11:
        NY_UPCs.append(str(df_NY['UPC/PLU Number'][i]))
    elif len(str(df_NY['UPC/PLU Number'][i]))==12:
        NY_UPCs.append(str(df_NY['UPC/PLU Number'][i])[1:12])
        
UPCs = IL_UPCs + MA_UPCs + MN_UPCs + NE_UPCs + NV_UPCs + NY_UPCs #combining
UPCs = list(set(UPCs)) #removes duplicate UPCs, and then coerces into a list

# %%
found, unfound = multiUPC_edamam(UPCs, verbose = True, leftovers = True, source="Edamam_API")
# Out:
# UPC  38000202117  exists in the API's data base
# UPC  688267070495  exists in the API's data base
# UPC  41190033294  exists in the API's data base
# UPC  41268202676  exists in the API's data base
# UPC  16000170117  does not exist in the API's data base
# UPC  11225124099  exists in the API's data base
# UPC  41190065004  exists in the API's data base
# UPC  16000264243  exists in the API's data base
# UPC  41268208388  exists in the API's data base
# UPC  84912320445  does not exist in the API's data base
# UPC  70038606925  does not exist in the API's data base
# UPC  42187541655  does not exist in the API's data base
# UPC  688267155758  exists in the API's data base
# UPC  18894110545  exists in the API's data base
# UPC  16000487697  exists in the API's data base
# UPC  36800110113  exists in the API's data base
# UPC  884912249265  exists in the API's data base
# UPC  884912006806  exists in the API's data base
# UPC  11110810106  exists in the API's data base
# UPC  11110878243  exists in the API's data base
# UPC  884912014283  exists in the API's data base
# UPC  41497537150  exists in the API's data base
# UPC  11110861641  exists in the API's data base
# UPC  75450081756  exists in the API's data base
# UPC  17544126904  does not exist in the API's data base
# UPC  38000291210  exists in the API's data base
# UPC  46567031804  exists in the API's data base
# UPC  15400862400  exists in the API's data base
# UPC  42400015932  exists in the API's data base
# UPC  15400874410  exists in the API's data base
# UPC  51933151208  exists in the API's data base
# UPC  41498220181  exists in the API's data base
# UPC  15400864060  exists in the API's data base
# UPC  38000049002  exists in the API's data base
# UPC  36800211629  exists in the API's data base
# UPC  88267169793  does not exist in the API's data base
# UPC  41270830775  does not exist in the API's data base
# UPC  884912017864  exists in the API's data base
# UPC  884912359155  does not exist in the API's data base
# UPC  30000012109  exists in the API's data base
# UPC  38000199400  exists in the API's data base
# UPC  74807099130  exists in the API's data base
# UPC  41735049407  exists in the API's data base
# UPC  49705017883  does not exist in the API's data base
# UPC  36800292086  exists in the API's data base
# UPC  38000395000  exists in the API's data base
# UPC  21130281152  exists in the API's data base
# UPC  16000183728  does not exist in the API's data base
# UPC  688267078736  exists in the API's data base
# UPC  38000049200  exists in the API's data base
# UPC  75130404059  exists in the API's data base
# UPC  50700031897  does not exist in the API's data base
# UPC  42400109037  exists in the API's data base
# UPC  42400178002  does not exist in the API's data base
# UPC  93476000282  does not exist in the API's data base
# UPC  16000410770  exists in the API's data base
# UPC  11110878700  exists in the API's data base
# UPC  30000064412  exists in the API's data base
# UPC  30000064030  exists in the API's data base
# UPC  51933342637  does not exist in the API's data base
# UPC  36800107472  exists in the API's data base
# UPC  70253298035  exists in the API's data base
# UPC  75450081893  exists in the API's data base
# UPC  38000198809  does not exist in the API's data base
# UPC  21333060615  does not exist in the API's data base
# UPC  36800188631  exists in the API's data base
# UPC  38000198656  does not exist in the API's data base
# UPC  41270019743  does not exist in the API's data base
# UPC  88267090998  does not exist in the API's data base
# UPC  84912003911  does not exist in the API's data base
# UPC  99771333102  does not exist in the API's data base
# UPC  884912014276  exists in the API's data base
# UPC  75450081800  exists in the API's data base
# UPC  42187425313  does not exist in the API's data base
# UPC  36800413511  exists in the API's data base
# UPC  16000161672  does not exist in the API's data base
# UPC  75450074260  exists in the API's data base
# UPC  11110876003  does not exist in the API's data base
# UPC  42400178019  exists in the API's data base
# UPC  70253298356  exists in the API's data base
# UPC  884912359162  does not exist in the API's data base
# UPC  36800617889  exists in the API's data base
# UPC  41190054008  exists in the API's data base
# UPC  38000256479  exists in the API's data base
# UPC  3811009  does not exist in the API's data base
# UPC  30000571132  does not exist in the API's data base
# UPC  21130280865  does not exist in the API's data base
# UPC  41268155828  does not exist in the API's data base
# UPC  725439103138  exists in the API's data base
# UPC  41270830799  does not exist in the API's data base
# UPC  16000137820  exists in the API's data base
# UPC  38000787270  exists in the API's data base
# UPC  13130060257  exists in the API's data base
# UPC  16000178182  does not exist in the API's data base
# UPC  41497532230  exists in the API's data base
# UPC  16000487956  exists in the API's data base
# UPC  16000275638  exists in the API's data base
# UPC  42400001362  exists in the API's data base
# UPC  70552801271  exists in the API's data base
# UPC  50700213712  does not exist in the API's data base
# UPC  79893116549  exists in the API's data base
# UPC  16000811607  exists in the API's data base
# UPC  30000317570  exists in the API's data base
# UPC  16000487963  exists in the API's data base
# UPC  35826074973  does not exist in the API's data base
# UPC  70784472171  exists in the API's data base
# UPC  41497538485  exists in the API's data base
# UPC  21130285877  exists in the API's data base
# UPC  16000301290  exists in the API's data base
# UPC  30000570241  does not exist in the API's data base
# UPC  41270812993  exists in the API's data base
# UPC  30000061107  exists in the API's data base
# UPC  42400016922  exists in the API's data base
# UPC  86341170558  exists in the API's data base
# UPC  688267065323  exists in the API's data base
# UPC  42400137559  exists in the API's data base
# UPC  49705105405  does not exist in the API's data base
# UPC  16000169623  does not exist in the API's data base
# UPC  11150100687  exists in the API's data base
# UPC  36800149724  exists in the API's data base
# UPC  41190053995  exists in the API's data base
# UPC  11161018360  exists in the API's data base
# UPC  884912126016  exists in the API's data base
# UPC  41303001844  exists in the API's data base
# UPC  78742230290  exists in the API's data base
# UPC  51933150300  exists in the API's data base
# UPC  70253298721  exists in the API's data base
# UPC  70038604204  does not exist in the API's data base
# UPC  84912259363  does not exist in the API's data base
# UPC  16000487970  exists in the API's data base
# UPC  38000469541  exists in the API's data base
# UPC  50700200682  does not exist in the API's data base
# UPC  11110851215  exists in the API's data base
# UPC  36800421745  exists in the API's data base
# UPC  15400862387  exists in the API's data base
# UPC  71518021856  exists in the API's data base
# UPC  88267078729  does not exist in the API's data base
# UPC  93476000183  does not exist in the API's data base
# UPC  71518021863  exists in the API's data base
# UPC  70552801141  exists in the API's data base
# UPC  42400109761  exists in the API's data base
# UPC  41497530441  does not exist in the API's data base
# UPC  11110844958  exists in the API's data base
# UPC  43000105214  exists in the API's data base
# UPC  41268108374  exists in the API's data base
# UPC  16000275157  exists in the API's data base
# UPC  688267169878  exists in the API's data base
# UPC  88267090981  does not exist in the API's data base
# UPC  688267065330  exists in the API's data base
# UPC  41270812979  exists in the API's data base
# UPC  50700742960  does not exist in the API's data base
# UPC  75450081701  exists in the API's data base
# UPC  16000275676  exists in the API's data base
# UPC  42400070887  exists in the API's data base
# UPC  41497537242  exists in the API's data base
# UPC  13733913997  does not exist in the API's data base
# UPC  38000198458  does not exist in the API's data base
# UPC  884912356291  does not exist in the API's data base
# UPC  38000231537  does not exist in the API's data base
# UPC  41303001967  exists in the API's data base
# UPC  73296034516  does not exist in the API's data base
# UPC  42187408750  does not exist in the API's data base
# UPC  38000924224  exists in the API's data base
# UPC  16000142442  does not exist in the API's data base
# UPC  79166933064  does not exist in the API's data base
# UPC  84912249265  does not exist in the API's data base
# UPC  78742147048  exists in the API's data base
# UPC  41735010179  exists in the API's data base
# UPC  11161018377  exists in the API's data base
# UPC  21130280193  exists in the API's data base
# UPC  16000401051  exists in the API's data base
# UPC  492310003206  exists in the API's data base
# UPC  99771333041  does not exist in the API's data base
# UPC  73296066104  does not exist in the API's data base
# UPC  41303042311  exists in the API's data base
# UPC  78742075648  exists in the API's data base
# UPC  41735022103  does not exist in the API's data base
# UPC  688267064517  exists in the API's data base
# UPC  41268203642  does not exist in the API's data base
# UPC  16000658509  exists in the API's data base
# UPC  41303046319  exists in the API's data base
# UPC  84912356178  does not exist in the API's data base
# UPC  72400060182  exists in the API's data base
# UPC  688267169663  exists in the API's data base
# UPC  75450075502  exists in the API's data base
# UPC  41268126378  exists in the API's data base
# UPC  11225421419  exists in the API's data base
# UPC  622261091001  does not exist in the API's data base
# UPC  70253297397  exists in the API's data base
# UPC  75436999068  exists in the API's data base
# UPC  11150302173  exists in the API's data base
# UPC  98487300577  exists in the API's data base
# UPC  72400062209  exists in the API's data base
# UPC  38000318467  exists in the API's data base
# UPC  23627050142  does not exist in the API's data base
# UPC  38527135325  does not exist in the API's data base
# UPC  42400925019  exists in the API's data base
# UPC  11161161868  exists in the API's data base
# UPC  84912359155  does not exist in the API's data base
# UPC  77890376980  exists in the API's data base
# UPC  49705017784  does not exist in the API's data base
# UPC  85239029848  exists in the API's data base
# UPC  78742183961  does not exist in the API's data base
# UPC  70038618348  does not exist in the API's data base
# UPC  23627050081  does not exist in the API's data base
# UPC  73296000160  does not exist in the API's data base
# UPC  30000565599  exists in the API's data base
# UPC  380000991707  does not exist in the API's data base
# UPC  21333060325  exists in the API's data base
# UPC  25439109895  does not exist in the API's data base
# UPC  38000597039  exists in the API's data base
# UPC  70784472157  exists in the API's data base
# UPC  36800421769  exists in the API's data base
# UPC  16000496965  does not exist in the API's data base
# UPC  41270045193  does not exist in the API's data base
# UPC  78742122113  exists in the API's data base
# UPC  11225124143  exists in the API's data base
# UPC  41735098535  exists in the API's data base
# UPC  38000001109  exists in the API's data base
# UPC  42400001065  exists in the API's data base
# UPC  16000435094  exists in the API's data base
# UPC  49705100585  does not exist in the API's data base
# UPC  21130152834  exists in the API's data base
# UPC  41497524839  exists in the API's data base
# UPC  49705005538  does not exist in the API's data base
# UPC  42400184690  exists in the API's data base
# UPC  11153040607  does not exist in the API's data base
# UPC  75450078183  exists in the API's data base
# UPC  74807099147  exists in the API's data base
# UPC  73296313604  exists in the API's data base
# UPC  41303001646  exists in the API's data base
# UPC  11161160397  exists in the API's data base
# UPC  75450074277  exists in the API's data base
# UPC  49705005255  does not exist in the API's data base
# UPC  78742121949  exists in the API's data base
# UPC  38000207501  exists in the API's data base
# UPC  38000937743  exists in the API's data base
# UPC  11110876096  does not exist in the API's data base
# UPC  70784472263  exists in the API's data base
# UPC  16000275645  exists in the API's data base
# UPC  75130414089  does not exist in the API's data base
# UPC  77890449110  does not exist in the API's data base
# UPC  75450074284  exists in the API's data base
# UPC  70784472706  exists in the API's data base
# UPC  688267134258  does not exist in the API's data base
# UPC  93476000206  does not exist in the API's data base
# UPC  16000487895  exists in the API's data base
# UPC  41498148928  exists in the API's data base
# UPC  85239013519  does not exist in the API's data base
# UPC  41303002124  exists in the API's data base
# UPC  43000112250  exists in the API's data base
# UPC  884912014245  exists in the API's data base
# UPC  41268147953  exists in the API's data base
# UPC  41498242350  exists in the API's data base
# UPC  884912359414  does not exist in the API's data base
# UPC  70038595571  exists in the API's data base
# UPC  38000196249  does not exist in the API's data base
# UPC  13733914024  does not exist in the API's data base
# UPC  70253279997  exists in the API's data base
# UPC  85239901441  exists in the API's data base
# UPC  18894110675  exists in the API's data base
# UPC  42400141808  exists in the API's data base
# UPC  16000275621  exists in the API's data base
# UPC  884912005632  exists in the API's data base
# UPC  70784472027  exists in the API's data base
# UPC  41303059883  exists in the API's data base
# UPC  84912359421  does not exist in the API's data base
# UPC  42400112747  exists in the API's data base
# UPC  41303004999  does not exist in the API's data base
# UPC  21130287765  exists in the API's data base
# UPC  38000208553  exists in the API's data base
# UPC  38000245664  does not exist in the API's data base
# UPC  38000224690  exists in the API's data base
# UPC  41190033348  exists in the API's data base
# UPC  41190046751  exists in the API's data base
# UPC  36800110229  does not exist in the API's data base
# UPC  35826071583  does not exist in the API's data base
# UPC  78742091204  exists in the API's data base
# UPC  15400874427  exists in the API's data base
# UPC  41190034246  exists in the API's data base
# UPC  41268108190  exists in the API's data base
# UPC  41268202706  exists in the API's data base
# UPC  41270830744  exists in the API's data base
# UPC  21859046001  exists in the API's data base
# UPC  23933102078  exists in the API's data base
# UPC  77890561171  exists in the API's data base
# UPC  42187408279  does not exist in the API's data base
# UPC  11225124075  exists in the API's data base
# UPC  16000658905  exists in the API's data base
# UPC  884912259363  exists in the API's data base
# UPC  21859046032  does not exist in the API's data base
# UPC  84912105103  does not exist in the API's data base
# UPC  84912126016  does not exist in the API's data base
# UPC  38000359828  exists in the API's data base
# UPC  16000487710  exists in the API's data base
# UPC  51933176102  does not exist in the API's data base
# UPC  77890455654  does not exist in the API's data base
# UPC  38000198670  does not exist in the API's data base
# UPC  42400057444  exists in the API's data base
# UPC  70253298301  exists in the API's data base
# UPC  46567001111  exists in the API's data base
# UPC  16000171022  does not exist in the API's data base
# UPC  70038622383  does not exist in the API's data base
# UPC  42400025542  exists in the API's data base
# UPC  688267132698  exists in the API's data base
# UPC  83921118951  does not exist in the API's data base
# UPC  35826028297  exists in the API's data base
# UPC  73296057096  exists in the API's data base
# UPC  38000199462  exists in the API's data base
# UPC  21333061001  exists in the API's data base
# UPC  17544135463  does not exist in the API's data base
# UPC  70253298752  exists in the API's data base
# UPC  77890392782  exists in the API's data base
# UPC  41303074893  does not exist in the API's data base
# UPC  21333060707  does not exist in the API's data base
# UPC  75450075496  exists in the API's data base
# UPC  19320013799  exists in the API's data base
# UPC  16000476080  exists in the API's data base
# UPC  36800558168  exists in the API's data base
# UPC  16000275263  exists in the API's data base
# UPC  84912109101  does not exist in the API's data base
# UPC  30000560846  exists in the API's data base
# UPC  73296034271  does not exist in the API's data base
# UPC  84912116505  does not exist in the API's data base
# UPC  16000176348  exists in the API's data base
# UPC  93476000145  does not exist in the API's data base
# UPC  78742122083  exists in the API's data base
# UPC  50700561240  exists in the API's data base
# UPC  38000200663  exists in the API's data base
# UPC  64144080304  exists in the API's data base
# UPC  41303001790  exists in the API's data base
# UPC  02185904601  does not exist in the API's data base
# UPC  11110833037  exists in the API's data base
# UPC  13130006965  exists in the API's data base
# UPC  11110810113  exists in the API's data base
# UPC  41735158420  does not exist in the API's data base
# UPC  21333061087  exists in the API's data base
# UPC  41268164219  exists in the API's data base
# UPC  77890375761  exists in the API's data base
# UPC  70253298424  exists in the API's data base
# UPC  884912001870  exists in the API's data base
# UPC  70253298790  exists in the API's data base
# UPC  16000168756  does not exist in the API's data base
# UPC  41190033287  exists in the API's data base
# UPC  84912356291  does not exist in the API's data base
# UPC  38000199349  exists in the API's data base
# UPC  41268108244  does not exist in the API's data base
# UPC  75450081008  exists in the API's data base
# UPC  30000320730  exists in the API's data base
# UPC  70038630388  exists in the API's data base
# UPC  36800188648  exists in the API's data base
# UPC  78742076201  exists in the API's data base
# UPC  11110853585  exists in the API's data base
# UPC  98487953131  exists in the API's data base
# UPC  11153042205  does not exist in the API's data base
# UPC  41270812962  exists in the API's data base
# UPC  70784472478  exists in the API's data base
# UPC  30000562376  exists in the API's data base
# UPC  16000275287  exists in the API's data base
# UPC  70038636892  does not exist in the API's data base
# UPC  78742030920  exists in the API's data base
# UPC  78742075747  exists in the API's data base
# UPC  41270830294  exists in the API's data base
# UPC  70253999376  exists in the API's data base
# UPC  42187428710  does not exist in the API's data base
# UPC  16000161641  does not exist in the API's data base
# UPC  43000014240  exists in the API's data base
# UPC  16000409453  exists in the API's data base
# UPC  41735088628  exists in the API's data base
# UPC  42400017912  exists in the API's data base
# UPC  64144080373  exists in the API's data base
# UPC  41735022134  does not exist in the API's data base
# UPC  41497537372  exists in the API's data base
# UPC  84912105219  does not exist in the API's data base
# UPC  38000200687  does not exist in the API's data base
# UPC  41190022687  exists in the API's data base
# UPC  38000214691  exists in the API's data base
# UPC  16000275591  exists in the API's data base
# UPC  16000663701  exists in the API's data base
# UPC  11161160540  exists in the API's data base
# UPC  11110666727  does not exist in the API's data base
# UPC  11110851970  exists in the API's data base
# UPC  41735088611  does not exist in the API's data base
# UPC  36800285941  exists in the API's data base
# UPC  11110853301  exists in the API's data base
# UPC  15400864077  exists in the API's data base
# UPC  11161015918  exists in the API's data base
# UPC  42400025238  exists in the API's data base
# UPC  16000184367  does not exist in the API's data base
# UPC  70038346753  does not exist in the API's data base
# UPC  50700259406  does not exist in the API's data base
# UPC  78742183954  does not exist in the API's data base
# UPC  21333061056  exists in the API's data base
# UPC  36800285958  exists in the API's data base
# UPC  84912377142  does not exist in the API's data base
# UPC  41497537006  exists in the API's data base
# UPC  30000316887  exists in the API's data base
# UPC  30000571842  does not exist in the API's data base
# UPC  16000275652  exists in the API's data base
# UPC  42400028758  exists in the API's data base
# UPC  16000171046  does not exist in the API's data base
# UPC  11110903372  exists in the API's data base
# UPC  51933150201  exists in the API's data base
# UPC  38000199943  exists in the API's data base
# UPC  16000169661  does not exist in the API's data base
# UPC  41303001905  exists in the API's data base
# UPC  41497537020  exists in the API's data base
# UPC  21130282869  exists in the API's data base
# UPC  16000423442  exists in the API's data base
# UPC  41190021796  exists in the API's data base
# UPC  75450075649  exists in the API's data base
# UPC  84912014249  does not exist in the API's data base
# UPC  41270830935  does not exist in the API's data base
# UPC  16000157651  does not exist in the API's data base
# UPC  70552801240  does not exist in the API's data base
# UPC  41270830300  does not exist in the API's data base
# UPC  77890396353  exists in the API's data base
# UPC  78742091310  exists in the API's data base
# UPC  41190758722  does not exist in the API's data base
# UPC  78742213286  exists in the API's data base
# UPC  38000027208  exists in the API's data base
# UPC  16000170124  does not exist in the API's data base
# UPC  41497538454  exists in the API's data base
# UPC  42400001058  exists in the API's data base
# UPC  11110898326  does not exist in the API's data base
# UPC  42400181521  exists in the API's data base
# UPC  77890455647  exists in the API's data base
# UPC  30000061531  does not exist in the API's data base
# UPC  688267091001  exists in the API's data base
# UPC  17544116981  does not exist in the API's data base
# UPC  74807099109  does not exist in the API's data base
# UPC  41190751556  does not exist in the API's data base
# UPC  42187425399  does not exist in the API's data base
# UPC  84912014270  does not exist in the API's data base
# UPC  99482438975  exists in the API's data base
# UPC  11110866530  exists in the API's data base
# UPC  11150301701  exists in the API's data base
# UPC  41190761876  does not exist in the API's data base
# UPC  88267064517  does not exist in the API's data base
# UPC  11225124082  exists in the API's data base
# UPC  73296034509  does not exist in the API's data base
# UPC  21859046124  does not exist in the API's data base
# UPC  193476000282  exists in the API's data base
# UPC  41498148850  exists in the API's data base
# UPC  42400068006  does not exist in the API's data base
# UPC  30000041703  exists in the API's data base
# UPC  16000139732  exists in the API's data base
# UPC  688267078729  exists in the API's data base
# UPC  75450075472  exists in the API's data base
# UPC  38000271021  does not exist in the API's data base
# UPC  41735012326  does not exist in the API's data base
# UPC  41303054772  exists in the API's data base
# UPC  16000487949  exists in the API's data base
# UPC  13733914017  does not exist in the API's data base
# UPC  13130006125  exists in the API's data base
# UPC  41270830256  does not exist in the API's data base
# UPC  11161160489  exists in the API's data base
# UPC  41268155255  does not exist in the API's data base
# UPC  30000061190  exists in the API's data base
# UPC  84912105400  does not exist in the API's data base
# UPC  50700742953  does not exist in the API's data base
# UPC  70253298196  exists in the API's data base
# UPC  38000199387  exists in the API's data base
# UPC  11110894694  exists in the API's data base
# UPC  11153040621  does not exist in the API's data base
# UPC  18894110644  exists in the API's data base
# UPC  51933151307  exists in the API's data base
# UPC  84912005632  does not exist in the API's data base
# UPC  884912320490  exists in the API's data base
# UPC  21333061018  exists in the API's data base
# UPC  41190756063  exists in the API's data base
# UPC  41303001868  exists in the API's data base
# UPC  75450084375  exists in the API's data base
# UPC  42400098003  exists in the API's data base
# UPC  41190054022  exists in the API's data base
# UPC  11110867056  exists in the API's data base
# UPC  36800422100  exists in the API's data base
# UPC  35826099136  exists in the API's data base
# UPC  41735158758  does not exist in the API's data base
# UPC  38000198632  does not exist in the API's data base
# UPC  78742056821  exists in the API's data base
# UPC  38000249891  does not exist in the API's data base
# UPC  70253298776  exists in the API's data base
# UPC  11161160588  exists in the API's data base
# UPC  43000112304  exists in the API's data base
# UPC  41268155804  does not exist in the API's data base
# UPC  11161020318  exists in the API's data base
# UPC  42400026815  exists in the API's data base
# UPC  49705010044  exists in the API's data base
# UPC  35826074997  exists in the API's data base
# UPC  49705005460  exists in the API's data base
# UPC  16000170032  does not exist in the API's data base
# UPC  16000275492  exists in the API's data base
# UPC  88267155758  does not exist in the API's data base
# UPC  16000103719  exists in the API's data base
# UPC  70784471648  does not exist in the API's data base
# UPC  16000666603  exists in the API's data base
# UPC  43000105405  exists in the API's data base
# UPC  41268108336  exists in the API's data base
# UPC  16000488366  exists in the API's data base
# UPC  41190751228  exists in the API's data base
# UPC  84912105107  does not exist in the API's data base
# UPC  725439109895  exists in the API's data base
# UPC  91669199104  does not exist in the API's data base
# UPC  18894115410  does not exist in the API's data base
# UPC  30000560839  exists in the API's data base
# UPC  30000064429  exists in the API's data base
# UPC  884912003928  exists in the API's data base
# UPC  41190763207  exists in the API's data base
# UPC  36800111103  exists in the API's data base
# UPC  38000596827  exists in the API's data base
# UPC  36800329805  exists in the API's data base
# UPC  688267090998  exists in the API's data base
# UPC  78742122090  exists in the API's data base
# UPC  70038618355  does not exist in the API's data base
# UPC  11161159940  exists in the API's data base
# UPC  99771333010  does not exist in the API's data base
# UPC  21333060905  exists in the API's data base
# UPC  75450152425  exists in the API's data base
# UPC  78742371689  exists in the API's data base
# UPC  30000061534  exists in the API's data base
# UPC  15400862325  does not exist in the API's data base
# UPC  688267169793  exists in the API's data base
# UPC  42187408903  does not exist in the API's data base
# UPC  35826100108  exists in the API's data base
# UPC  11110853509  exists in the API's data base
# UPC  11110819994  does not exist in the API's data base
# UPC  70784472294  does not exist in the API's data base
# UPC  16000442894  exists in the API's data base
# UPC  36800317581  exists in the API's data base
# UPC  41270830409  does not exist in the API's data base
# UPC  70784472164  does not exist in the API's data base
# UPC  21130282944  exists in the API's data base
# UPC  38000199578  exists in the API's data base
# UPC  15400862332  exists in the API's data base
# UPC  41270016650  exists in the API's data base
# UPC  38000300011  exists in the API's data base
# UPC  75450082470  exists in the API's data base
# UPC  17544100423  does not exist in the API's data base
# UPC  41270830843  exists in the API's data base
# UPC  84912014269  does not exist in the API's data base
# UPC  41497537334  exists in the API's data base
# UPC  11110787118  exists in the API's data base
# UPC  17544134893  does not exist in the API's data base
# UPC  13733914031  does not exist in the API's data base
# UPC  50700301518  does not exist in the API's data base
# UPC  41735079251  exists in the API's data base
# UPC  42400062370  exists in the API's data base
# UPC  42400071983  exists in the API's data base
# UPC  70253280306  does not exist in the API's data base
# UPC  41497535453  exists in the API's data base
# UPC  01600027549  exists in the API's data base
# UPC  13130006989  exists in the API's data base
# UPC  18000630806  exists in the API's data base
# UPC  41270024310  exists in the API's data base
# UPC  11161018353  exists in the API's data base
# UPC  46567011936  exists in the API's data base
# UPC  17544135470  does not exist in the API's data base
# UPC  51933347588  exists in the API's data base
# UPC  11150301909  does not exist in the API's data base
# UPC  11161036661  exists in the API's data base
# UPC  41270061056  exists in the API's data base
# UPC  70784478906  exists in the API's data base
# UPC  13130006224  exists in the API's data base
# UPC  41268203659  does not exist in the API's data base
# UPC  35826003690  does not exist in the API's data base
# UPC  41270041461  does not exist in the API's data base
# UPC  15400820998  exists in the API's data base
# UPC  49705105351  does not exist in the API's data base
# UPC  884912014252  exists in the API's data base
# UPC  78328031006  does not exist in the API's data base
# UPC  88267169762  does not exist in the API's data base
# UPC  84912014263  does not exist in the API's data base
# UPC  78742181479  exists in the API's data base
# UPC  38000991707  exists in the API's data base
# UPC  50700030111  does not exist in the API's data base
# UPC  16000427242  exists in the API's data base
# UPC  38000199554  exists in the API's data base
# UPC  78742075778  exists in the API's data base
# UPC  73296057058  exists in the API's data base
# UPC  84912004727  does not exist in the API's data base
# UPC  98487300560  exists in the API's data base
# UPC  30000317556  does not exist in the API's data base
# UPC  15400853965  does not exist in the API's data base
# UPC  84912105213  does not exist in the API's data base
# UPC  23933002019  exists in the API's data base
# UPC  42400184706  exists in the API's data base
# UPC  36800149700  exists in the API's data base
# UPC  884912181701  exists in the API's data base
# UPC  688267090981  exists in the API's data base
# UPC  71923761576  exists in the API's data base
# UPC  884912014467  exists in the API's data base
# UPC  884912006813  exists in the API's data base
# UPC  30000567661  exists in the API's data base
# UPC  70784472713  exists in the API's data base
# UPC  84912006806  does not exist in the API's data base
# UPC  41268164226  does not exist in the API's data base
# UPC  17544100355  does not exist in the API's data base
# UPC  11225079207  exists in the API's data base
# UPC  72543910245  does not exist in the API's data base
# UPC  71923761453  does not exist in the API's data base
# UPC  77890463932  does not exist in the API's data base
# UPC  84912014276  does not exist in the API's data base
# UPC  884912105219  exists in the API's data base
# UPC  30000313282  exists in the API's data base
# UPC  78742121789  exists in the API's data base
# UPC  41303059869  exists in the API's data base
# UPC  21130282777  exists in the API's data base
# UPC  15400838108  exists in the API's data base
# UPC  38000016110  exists in the API's data base
# UPC  70038633990  does not exist in the API's data base
# UPC  51933049802  exists in the API's data base
# UPC  38000231452  does not exist in the API's data base
# UPC  41268155835  does not exist in the API's data base
# UPC  38527135301  exists in the API's data base
# UPC  42187428734  does not exist in the API's data base
# UPC  75130414041  exists in the API's data base
# UPC  42400145998  does not exist in the API's data base
# UPC  38000576195  exists in the API's data base
# UPC  38000191817  exists in the API's data base
# UPC  49705017968  exists in the API's data base
# UPC  84912003928  does not exist in the API's data base
# UPC  18894110453  exists in the API's data base
# UPC  41268204441  does not exist in the API's data base
# UPC  43000105108  exists in the API's data base
# UPC  41270830751  exists in the API's data base
# UPC  15400838184  exists in the API's data base
# UPC  16000152922  does not exist in the API's data base
# UPC  84912017864  does not exist in the API's data base
# UPC  11110850645  exists in the API's data base
# UPC  11153040911  does not exist in the API's data base
# UPC  41303059876  exists in the API's data base
# UPC  36800291881  exists in the API's data base
# UPC  75450082258  does not exist in the API's data base
# UPC  42400905011  exists in the API's data base
# UPC  84912014306  does not exist in the API's data base
# UPC  21130285860  exists in the API's data base
# UPC  01600013782  does not exist in the API's data base
# UPC  46567001142  exists in the API's data base
# UPC  42400181545  exists in the API's data base
# UPC  30000565605  exists in the API's data base
# UPC  51933515208  does not exist in the API's data base
# UPC  78742122076  exists in the API's data base
# UPC  43000113134  exists in the API's data base
# UPC  41318292268  exists in the API's data base
# UPC  38000196218  exists in the API's data base
# UPC  884912004727  exists in the API's data base
# UPC  78742075839  exists in the API's data base
# UPC  21333060813  does not exist in the API's data base
# UPC  41270813563  exists in the API's data base
# UPC  16000625709  exists in the API's data base
# UPC  75450127942  exists in the API's data base
# UPC  35826100115  does not exist in the API's data base
# UPC  884912249272  exists in the API's data base
# UPC  42400084778  exists in the API's data base
# UPC  38000199509  exists in the API's data base
# UPC  38000596674  exists in the API's data base
# UPC  41318290189  exists in the API's data base
# UPC  50700561196  exists in the API's data base
# UPC  24300031625  exists in the API's data base
# UPC  70038342878  does not exist in the API's data base
# UPC  688267064524  exists in the API's data base
# UPC  42187408989  does not exist in the API's data base
# UPC  41497530052  exists in the API's data base
# UPC  38000200038  exists in the API's data base
# UPC  84912014290  does not exist in the API's data base
# UPC  49705005545  does not exist in the API's data base
# UPC  98487952356  exists in the API's data base
# UPC  50700561288  does not exist in the API's data base
# UPC  13733913867  does not exist in the API's data base
# UPC  85239906316  exists in the API's data base
# UPC  30000064037  does not exist in the API's data base
# UPC  21859046155  exists in the API's data base
# UPC  38000212154  exists in the API's data base
# UPC  41735050106  does not exist in the API's data base
# UPC  70552801257  exists in the API's data base
# UPC  38000027277  exists in the API's data base
# UPC  38000281686  does not exist in the API's data base
# UPC  688267129360  exists in the API's data base
# UPC  42187425382  does not exist in the API's data base
# UPC  21130281251  exists in the API's data base
# UPC  11110878298  exists in the API's data base
# UPC  50700561202  exists in the API's data base
# UPC  41512082931  exists in the API's data base
# UPC  70038592150  does not exist in the API's data base
# UPC  50700007526  does not exist in the API's data base
# UPC  11225124136  exists in the API's data base
# UPC  41190756742  does not exist in the API's data base
# UPC  42187029245  does not exist in the API's data base
# UPC  78742140988  exists in the API's data base
# UPC  38000001277  exists in the API's data base
# UPC  21130280025  exists in the API's data base
# UPC  193476000206  exists in the API's data base
# UPC  88267169878  does not exist in the API's data base
# UPC  78742230337  exists in the API's data base
# UPC  36800114128  exists in the API's data base
# UPC  38000245688  exists in the API's data base
# UPC  30000315071  exists in the API's data base
# UPC  36800285965  exists in the API's data base
# UPC  78742181530  exists in the API's data base
# UPC  84912004710  does not exist in the API's data base
# UPC  42187410104  does not exist in the API's data base
# UPC  17544100539  does not exist in the API's data base
# UPC  16000171084  does not exist in the API's data base
# UPC  70784472034  exists in the API's data base
# UPC  18894110286  exists in the API's data base
# UPC  41735158437  does not exist in the API's data base
# UPC  38000200267  does not exist in the API's data base
# UPC  884912377142  does not exist in the API's data base
# UPC  42187428628  does not exist in the API's data base
# UPC  42400058007  exists in the API's data base
# UPC  78742121918  exists in the API's data base
# UPC  46567007939  exists in the API's data base
# UPC  11161160502  exists in the API's data base
# UPC  16000176829  exists in the API's data base
# UPC  50700271897  does not exist in the API's data base
# UPC  36800421738  exists in the API's data base
# UPC  83921118975  does not exist in the API's data base
# UPC  41497530069  exists in the API's data base
# UPC  41303059852  exists in the API's data base
# UPC  41735096791  does not exist in the API's data base
# UPC  18894110200  exists in the API's data base
# UPC  42187541563  does not exist in the API's data base
# UPC  88267078675  does not exist in the API's data base
# UPC  77890437469  exists in the API's data base
# UPC  41303001653  exists in the API's data base
# UPC  36800318502  exists in the API's data base
# UPC  99771333034  does not exist in the API's data base
# UPC  42400107934  exists in the API's data base
# UPC  688267112034  exists in the API's data base
# UPC  41190033300  exists in the API's data base
# UPC  13130006026  exists in the API's data base
# UPC  41303001615  exists in the API's data base
# UPC  70784471662  does not exist in the API's data base
# UPC  21130280360  exists in the API's data base
# UPC  11110853929  exists in the API's data base
# UPC  16000123151  exists in the API's data base
# UPC  30000063545  exists in the API's data base
# UPC  21130282562  exists in the API's data base
# UPC  91669366896  does not exist in the API's data base
# UPC  84912320490  does not exist in the API's data base
# UPC  36800448643  exists in the API's data base
# UPC  884912109101  exists in the API's data base
# UPC  41735159168  does not exist in the API's data base
# UPC  51933049703  exists in the API's data base
# UPC  30000313466  exists in the API's data base
# UPC  50700286433  exists in the API's data base
# UPC  38000143670  exists in the API's data base
# UPC  17544116974  does not exist in the API's data base
# UPC  46567014050  exists in the API's data base
# UPC  35826074980  exists in the API's data base
# UPC  11110878274  exists in the API's data base
# UPC  16000662100  exists in the API's data base
# UPC  75450033588  exists in the API's data base
# UPC  42187001845  does not exist in the API's data base
# UPC  30000063408  exists in the API's data base
# UPC  49705018569  does not exist in the API's data base
# UPC  16000137653  exists in the API's data base
# UPC  70038592129  exists in the API's data base
# UPC  38000199363  does not exist in the API's data base
# UPC  86341170541  exists in the API's data base
# UPC  11225421358  exists in the API's data base
# UPC  884912320445  does not exist in the API's data base
# UPC  41735015181  does not exist in the API's data base
# UPC  50700303659  does not exist in the API's data base
# UPC  30000064419  does not exist in the API's data base
# UPC  78742181509  exists in the API's data base
# UPC  78742183947  exists in the API's data base
# UPC  41318291421  exists in the API's data base
# UPC  41497537297  does not exist in the API's data base
# UPC  884912116505  exists in the API's data base
# UPC  70038618461  does not exist in the API's data base
# UPC  15400864084  exists in the API's data base
# UPC  42400016045  exists in the API's data base
# UPC  77890320365  exists in the API's data base
# UPC  16000148239  does not exist in the API's data base
# UPC  18894110279  exists in the API's data base
# UPC  41303001950  exists in the API's data base
# UPC  36800448025  does not exist in the API's data base
# UPC  16000170070  does not exist in the API's data base
# UPC  36800188679  exists in the API's data base
# UPC  78742121758  exists in the API's data base
# UPC  84912014252  does not exist in the API's data base
# UPC  70253279201  exists in the API's data base
# UPC  18894115397  does not exist in the API's data base
# UPC  78742122120  exists in the API's data base
# UPC  51933342620  exists in the API's data base
# UPC  41735050007  exists in the API's data base
# UPC  46567031798  exists in the API's data base
# UPC  11110787088  exists in the API's data base
# UPC  16000487987  exists in the API's data base
# UPC  16000163928  does not exist in the API's data base
# UPC  30000061503  exists in the API's data base
# UPC  16000492349  exists in the API's data base
# UPC  11153040690  does not exist in the API's data base
# UPC  78742121765  exists in the API's data base
# UPC  84912006813  does not exist in the API's data base
# UPC  17544127925  does not exist in the API's data base
# UPC  70784472355  does not exist in the API's data base
# UPC  75130404172  exists in the API's data base
# UPC  75436999044  does not exist in the API's data base
# UPC  41268202744  exists in the API's data base
# UPC  11225020889  exists in the API's data base
# UPC  41303001899  exists in the API's data base
# UPC  70552801370  exists in the API's data base
# UPC  75130414027  exists in the API's data base
# UPC  41303085493  exists in the API's data base
# UPC  21130280568  exists in the API's data base
# UPC  46567031811  exists in the API's data base
# UPC  43000116500  exists in the API's data base
# UPC  16000157620  does not exist in the API's data base
# UPC  884912004710  exists in the API's data base
# UPC  38000198823  does not exist in the API's data base
# UPC  83921118999  does not exist in the API's data base
# UPC  41190046775  exists in the API's data base
# UPC  11153041901  exists in the API's data base
# UPC  41497537310  exists in the API's data base
# UPC  11225024603  exists in the API's data base
# UPC  41735088604  does not exist in the API's data base
# UPC  11225124044  exists in the API's data base
# UPC  70038639985  exists in the API's data base
# UPC  75130414072  exists in the API's data base
# UPC  688267065316  exists in the API's data base
# UPC  70038304821  exists in the API's data base
# UPC  70784472652  exists in the API's data base
# UPC  11153041857  does not exist in the API's data base
# UPC  35882007010  does not exist in the API's data base
# UPC  41303001783  exists in the API's data base
# UPC  42400146322  exists in the API's data base
# UPC  38000269967  does not exist in the API's data base
# UPC  38000202124  does not exist in the API's data base
# UPC  38000218163  exists in the API's data base
# UPC  78742181486  exists in the API's data base
# UPC  84912359162  does not exist in the API's data base
# UPC  88267070471  does not exist in the API's data base
# UPC  42400001096  exists in the API's data base
# UPC  41268203635  exists in the API's data base
# UPC  38000016219  exists in the API's data base
# UPC  70253298707  exists in the API's data base
# UPC  16000275782  exists in the API's data base
# UPC  11110866394  does not exist in the API's data base
# UPC  41268209095  exists in the API's data base
# UPC  75130404370  exists in the API's data base
# UPC  88267070495  does not exist in the API's data base
# UPC  70038324256  exists in the API's data base
# UPC  91669403034  does not exist in the API's data base
# UPC  88267193804  does not exist in the API's data base
# UPC  42400137320  exists in the API's data base
# UPC  30000319291  exists in the API's data base
# UPC  78742181554  exists in the API's data base
# UPC  38000482809  exists in the API's data base
# UPC  84912014245  does not exist in the API's data base
# UPC  38000001208  exists in the API's data base
# UPC  38000224713  exists in the API's data base
# UPC  46567014432  exists in the API's data base
# UPC  98487953032  exists in the API's data base
# UPC  42187408972  does not exist in the API's data base
# UPC  21130152841  exists in the API's data base
# UPC  92310001233  does not exist in the API's data base
# UPC  38000318344  exists in the API's data base
# UPC  21859046148  does not exist in the API's data base
# UPC  15400840835  exists in the API's data base
# UPC  884912356178  exists in the API's data base
# UPC  884912006233  exists in the API's data base
# UPC  43000014257  exists in the API's data base
# UPC  38000318290  exists in the API's data base
# UPC  70038595489  does not exist in the API's data base
# UPC  77890396391  exists in the API's data base
# UPC  30000047606  exists in the API's data base
# UPC  70038589136  does not exist in the API's data base
# UPC  21130280322  exists in the API's data base
# UPC  16000170094  does not exist in the API's data base
# UPC  20794012293  does not exist in the API's data base
# UPC  75450075625  exists in the API's data base
# UPC  15400874434  exists in the API's data base
# UPC  38000201288  exists in the API's data base
# UPC  49705017807  does not exist in the API's data base
# UPC  11110857408  exists in the API's data base
# UPC  38000199592  exists in the API's data base
# UPC  16000275584  exists in the API's data base
# UPC  49705005453  does not exist in the API's data base
# UPC  21333060011  exists in the API's data base
# UPC  43000112403  exists in the API's data base
# UPC  38000202094  exists in the API's data base
# UPC  50700012971  does not exist in the API's data base
# UPC  41268124091  exists in the API's data base
# UPC  75450169454  exists in the API's data base
# UPC  41270061070  exists in the API's data base
# UPC  84912249272  does not exist in the API's data base
# UPC  88267064524  does not exist in the API's data base
# UPC  49705005507  does not exist in the API's data base
# UPC  30000065709  exists in the API's data base
# UPC  21333060066  exists in the API's data base
# UPC  64144080328  exists in the API's data base
# UPC  884912012791  exists in the API's data base
# UPC  21130281534  exists in the API's data base
# UPC  21859046100  exists in the API's data base
# UPC  78742358864  exists in the API's data base
# UPC  42400240853  exists in the API's data base
# UPC  884912001863  exists in the API's data base
# UPC  30000060056  exists in the API's data base
# UPC  11161159599  exists in the API's data base
# UPC  51933176126  exists in the API's data base
# UPC  884912259370  exists in the API's data base
# UPC  15400820981  exists in the API's data base
# UPC  16000898592  does not exist in the API's data base
# UPC  38000035302  exists in the API's data base
# UPC  688267169762  exists in the API's data base
# UPC  84912113139  exists in the API's data base
# UPC  41268108275  exists in the API's data base
# UPC  15400853934  exists in the API's data base
# UPC  16000139756  does not exist in the API's data base
# UPC  11161160670  exists in the API's data base
# UPC  93476000190  does not exist in the API's data base
# UPC  70784471686  exists in the API's data base
# UPC  42400001041  exists in the API's data base
# UPC  75450081879  exists in the API's data base
# UPC  70038639893  does not exist in the API's data base
# UPC  41303001929  exists in the API's data base
# UPC  42187541556  does not exist in the API's data base
# UPC  49705017937  exists in the API's data base
# UPC  50700070124  does not exist in the API's data base
# UPC  11110032454  exists in the API's data base
# UPC  85239901151  exists in the API's data base
# UPC  41190759590  does not exist in the API's data base
# UPC  91669252762  does not exist in the API's data base
# UPC  16000487727  exists in the API's data base
# UPC  41303001912  exists in the API's data base
# UPC  41303001820  exists in the API's data base
# UPC  16000170995  does not exist in the API's data base
# UPC  41270045704  exists in the API's data base
# UPC  884912014269  exists in the API's data base
# UPC  42400178057  exists in the API's data base
# UPC  41512093357  exists in the API's data base
# UPC  35826100122  does not exist in the API's data base
# UPC  41190762019  exists in the API's data base
# UPC  11110905994  exists in the API's data base
# UPC  30000041307  exists in the API's data base
# UPC  13130006118  exists in the API's data base
# UPC  36800402782  exists in the API's data base
# UPC  42400070993  exists in the API's data base
# UPC  84912014256  does not exist in the API's data base
# UPC  70253298066  exists in the API's data base
# UPC  50700552996  does not exist in the API's data base
# UPC  41190756070  does not exist in the API's data base
# UPC  41303001981  exists in the API's data base
# UPC  42400141303  exists in the API's data base
# UPC  70552801387  exists in the API's data base
# UPC  41735088635  does not exist in the API's data base
# UPC  18894110446  does not exist in the API's data base
# UPC  72400000256  exists in the API's data base
# UPC  86341170503  exists in the API's data base
# UPC  42400181538  exists in the API's data base
# UPC  30000064306  exists in the API's data base
# UPC  42400047483  exists in the API's data base
# UPC  41303001943  exists in the API's data base
# UPC  38000270864  does not exist in the API's data base
# UPC  41268155842  does not exist in the API's data base
# UPC  41268203611  exists in the API's data base
# UPC  21333061025  exists in the API's data base
# UPC  16000125414  exists in the API's data base
# UPC  688267193804  exists in the API's data base
# UPC  41268164202  does not exist in the API's data base
# UPC  43000112243  exists in the API's data base
# UPC  11535507284  does not exist in the API's data base
# UPC  41497530434  exists in the API's data base
# UPC  38000199530  exists in the API's data base
# UPC  884912359421  does not exist in the API's data base
# UPC  43000109342  exists in the API's data base
# UPC  11225130458  exists in the API's data base
# UPC  50700552330  does not exist in the API's data base
# UPC  725439103121  does not exist in the API's data base
# UPC  42400108177  exists in the API's data base
# UPC  11161029175  exists in the API's data base
# UPC  38000198410  exists in the API's data base
# UPC  70253280290  exists in the API's data base
# UPC  42400055075  does not exist in the API's data base
# UPC  91669300388  does not exist in the API's data base
# UPC  884912012784  exists in the API's data base
# UPC  21859046209  exists in the API's data base
# UPC  688267135750  exists in the API's data base
# UPC  21130280490  exists in the API's data base
# UPC  11110853110  exists in the API's data base
# UPC  70784471983  exists in the API's data base
# UPC  36800110175  exists in the API's data base
# UPC  11110907585  does not exist in the API's data base
# UPC  41270040914  exists in the API's data base
# UPC  11110809414  exists in the API's data base
# UPC  13733914000  does not exist in the API's data base
# UPC  725439103091  exists in the API's data base
# UPC  42187001500  does not exist in the API's data base
# UPC  91669301224  does not exist in the API's data base
# UPC  42400142997  exists in the API's data base
# UPC  20794011760  does not exist in the API's data base
# UPC  42400267157  exists in the API's data base
# UPC  41270830928  exists in the API's data base
# UPC  30000040508  exists in the API's data base
# UPC  11110853530  exists in the API's data base
# UPC  78742181493  exists in the API's data base
# UPC  88267091001  does not exist in the API's data base
# UPC  78742121703  exists in the API's data base
# UPC  99482438869  exists in the API's data base
# UPC  884912003911  exists in the API's data base
# UPC  38000470820  does not exist in the API's data base
# UPC  70552801233  exists in the API's data base
# UPC  884912014306  exists in the API's data base
# UPC  49705009963  does not exist in the API's data base
# UPC  41735022127  does not exist in the API's data base
# UPC  41190046744  exists in the API's data base
# UPC  88267065316  does not exist in the API's data base
# UPC  11110825698  does not exist in the API's data base
# UPC  36800399730  exists in the API's data base
# UPC  42400172659  exists in the API's data base
# UPC  21333060110  exists in the API's data base
# UPC  11161161851  exists in the API's data base
# UPC  78742075273  exists in the API's data base
# UPC  16000898257  does not exist in the API's data base
# UPC  77890418536  does not exist in the API's data base
# UPC  11110029065  does not exist in the API's data base
# UPC  41270448581  does not exist in the API's data base
# UPC  86341170534  exists in the API's data base
# UPC  41190046768  exists in the API's data base
# UPC  38000014116  exists in the API's data base
# UPC  49705010006  exists in the API's data base
# UPC  21333060943  exists in the API's data base
# UPC  38000200243  does not exist in the API's data base
# UPC  16000275058  exists in the API's data base
# UPC  75450069303  does not exist in the API's data base
# UPC  71923761583  does not exist in the API's data base
# UPC  70784472409  exists in the API's data base
# UPC  688267078675  exists in the API's data base

# %%
Found = pd.DataFrame(found)
Missing = pd.DataFrame(unfound)
print('There are ', len(Missing), ' missing UPCs.')
print('There are ', len(Found), ' found UPCs.')
# Out:
# There are  341  missing UPCs.
# There are  690  found UPCs.

# %%
# Save raw data from Excel before making any changes
Found.to_excel("edamam_Raw.xlsx", sheet_name='Cereal Data')
Found
# Out:
#      ENERC_KCAL        FAT     FASAT  FATRN      FAMS      FAPU     CHOCDF  \
# 0    339.000000   1.790000  0.000000    0.0  0.000000  0.000000  83.930000
# 1    352.739619   0.000000  0.000000    0.0  0.000000  0.000000  84.657509
# 2    357.000000   0.000000  0.000000    0.0  0.000000  0.000000  85.709999
# 3    345.000000   1.820000  0.000000    0.0  0.000000  0.910000  83.639999
# 4    406.000000   0.000000  0.000000    0.0  0.000000  0.000000  87.500000
# 5    366.000000   6.100000  0.000000    0.0  2.440000  2.440000  73.169998
# 6    357.142857   7.142857  0.000000    0.0       NaN       NaN  71.428571
# 7    381.000000   4.760000  0.000000    0.0       NaN       NaN  78.570000
# 8     67.628045   0.845351  0.000000    0.0  0.000000  0.281784  14.089176
# 9    394.000000   0.000000  0.000000    0.0  0.000000  0.000000  87.879997
# 10   379.310345   3.448276  0.000000    0.0       NaN       NaN  82.758621
# 11   357.000000   0.000000  0.000000    0.0       NaN       NaN  85.709999
# 12   405.000000   7.140000       NaN    0.0  3.570000  1.190000  80.949997
# 13   400.000000   5.000000  0.000000    0.0  3.330000  0.000000  83.330002
# 14   375.000000   3.120000  0.000000    0.0  0.000000  0.000000  78.120003
# 15   345.000000   1.720000  0.000000    0.0  0.000000  0.860000  82.760002
# 16   406.000000   7.810000  0.000000    0.0  4.690000  1.560000  81.250000
# 17   370.000000   0.000000  0.000000    0.0  0.000000  0.000000  85.190002
# 18   375.000000   4.460000  0.890000    0.0  1.790000  1.790000  78.570000
# 19   380.405479   1.902027  0.000000    0.0       NaN       NaN  79.885151
# 20   394.000000   0.000000  0.000000    0.0  0.000000  0.000000  87.879997
# 21   370.000000   0.000000  0.000000    0.0  0.000000  0.000000  85.190002
# 22   340.000000   2.130000  0.000000    0.0  0.000000  1.060000  82.980003
# 23   394.000000   9.090000  1.520000    0.0  3.030000  3.030000  63.639999
# 24   357.000000   5.360000  0.000000    0.0  1.790000  1.790000  75.000000
# 25   367.000000   0.000000  0.000000    0.0       NaN       NaN  86.669998
# 26   346.247495   1.731237  0.000000    0.0  0.000000  0.000000  77.905686
# 27   357.142857   3.571429  0.000000    0.0       NaN       NaN  75.000000
# 28   334.174376   1.670872  0.000000    0.0       NaN       NaN  80.201850
# 29   394.000000   0.000000  0.000000    0.0  0.000000  0.000000  87.879997
# 30   393.000000   5.360000  0.000000    0.0  2.680000  1.790000  82.139999
# 31   357.000000   7.140000  1.790000    0.0  1.790000  1.790000  67.860001
# 32   350.000000   1.670000  0.000000    0.0  0.000000  0.830000  85.000000
# 33   400.000000   3.330000  0.000000    0.0  0.000000  0.000000  76.669998
# 34   357.142857   5.357143  0.000000    0.0  1.785714  1.785714  64.285714
# 35   349.000000   1.590000  0.000000    0.0  0.000000  0.790000  82.540001
# 36   394.000000   0.000000  0.000000    0.0  0.000000  0.000000  87
#  '84912003928',
#  '41268204441',
#  '16000152922',
#  '84912017864',
#  '11153040911',
#  '75450082258',
#  '84912014306',
#  '01600013782',
#  '51933515208',
#  '21333060813',
#  '35826100115',
#  '70038342878',
#  '42187408989',
#  '84912014290',
#  '49705005545',
#  '50700561288',
#  '13733913867',
#  '30000064037',
#  '41735050106',
#  '38000281686',
#  '42187425382',
#  '70038592150',
#  '50700007526',
#  '41190756742',
#  '42187029245',
#  '88267169878',
#  '84912004710',
#  '42187410104',
#  '17544100539',
#  '16000171084',
#  '41735158437',
#  '38000200267',
#  '884912377142',
#  '42187428628',
#  '50700271897',
#  '83921118975',
#  '41735096791',
#  '42187541563',
#  '88267078675',
#  '99771333034',
#  '70784471662',
#  '91669366896',
#  '84912320490',
#  '41735159168',
#  '17544116974',
#  '42187001845',
#  '49705018569',
#  '38000199363',
#  '884912320445',
#  '41735015181',
#  '50700303659',
#  '30000064419',
#  '41497537297',
#  '70038618461',
#  '16000148239',
#  '36800448025',
#  '16000170070',
#  '84912014252',
#  '18894115397',
#  '16000163928',
#  '11153040690',
#  '84912006813',
#  '17544127925',
#  '70784472355',
#  '75436999044',
#  '16000157620',
#  '38000198823',
#  '83921118999',
#  '41735088604',
#  '11153041857',
#  '35882007010',
#  '38000269967',
#  '38000202124',
#  '84912359162',
#  '88267070471',
#  '11110866394',
#  '88267070495',
#  '91669403034',
#  '88267193804',
#  '84912014245',
#  '42187408972',
#  '92310001233',
#  '21859046148',
#  '70038595489',
#  '70038589136',
#  '16000170094',
#  '20794012293',
#  '49705017807',
#  '49705005453',
#  '50700012971',
#  '84912249272',
#  '88267064524',
#  '49705005507',
#  '16000898592',
#  '16000139756',
#  '93476000190',
#  '70038639893',
#  '42187541556',
#  '50700070124',
#  '41190759590',
#  '91669252762',
#  '16000170995',
#  '35826100122',
#  '84912014256',
#  '50700552996',
#  '41190756070',
#  '41735088635',
#  '18894110446',
#  '38000270864',
#  '41268155842',
#  '41268164202',
#  '11535507284',
#  '884912359421',
#  '50700552330',
#  '725439103121',
#  '42400055075',
#  '91669300388',
#  '11110907585',
#  '13733914000',
#  '42187001500',
#  '91669301224',
#  '20794011760',
#  '88267091001',
#  '38000470820',
#  '49705009963',
#  '41735022127',
#  '88267065316',
#  '11110825698',
#  '16000898257',
#  '77890418536',
#  '11110029065',
#  '41270448581',
#  '38000200243',
#  '75450069303',
#  '71923761583']

# %%
my_id = os.environ["NUTRITIONIX_API_id"]
my_key = os.environ["NUTRITIONIX_API_key"]

baseURL = "https://trackapi.nutritionix.com/v2/search/item?upc="

HEADERS = {
    "x-app-id" : my_id,
    "x-app-key" : my_key,
    "Content-Type" : "application/json"
}

# %%
def inquiry(upc,source=""):
    try:        
        url = nutritionix_baseURL+upc
        r = requests.get(url, headers=nutritionix_HEADERS).json()
        r2 = r["foods"][0]
        r2["UPC"]  = upc
        r2["source"] = source
        return r2
    except:
        return "UPC could not be found"

# %%
def translate_N2E(d):
    #this function gets a reply from Nutrtionix API in a form of a dictionary 
    # and translates it into a dictionary in the form of Edamam's API

    iron = None
    ca = None
    trans = None
    vitd = None
    sugr_ad = None
    lb = d["brand_name"] + ", " + d["food_name"]
    
    for dd in d["full_nutrients"]:
        attr_id = dd["attr_id"]
        val = dd["value"]
        if attr_id == 303:
            iron = val        
        elif attr_id == 301:
            ca = val
        elif attr_id == 605:
            trans = val
        elif attr_id == 324:
            vitd = val
        elif attr_id == 539:
            sugr_ad = val
        
    new_d = {
        "label" : lb,
        "ENERC_KCAL" : d["nf_calories"],
        "FAT" : d["nf_total_fat"],
        "FASAT" : d["nf_saturated_fat"],
        "FATRN" : trans,
        "CHOLE" : d["nf_cholesterol"],
        "NA" : d["nf_sodium"],
        "CHOCDF" : d["nf_total_carbohydrate"],
        "FIBTG" : d["nf_dietary_fiber"],
        "SUGAR" : d["nf_sugars"],
        "SUGAR.added" : sugr_ad,
        "PROCNT" : d["nf_protein"],
        "VITD" : vitd,
        "P" : d["nf_potassium"],
        "FE" : iron,
        "CA" : ca,
        "servingSize_cup" : d["serving_qty"],
        "servingSize_gram" : d["serving_weight_grams"],
        "upc" : d["UPC"],
        "dataSource" : d["source"]
        }
    
    return new_d

# %%
#Used up Nutrix calls with debugging

""""
frames = []
for i in range(1):
    check = inquiry(Missing_UPCs[0]) # Already checked 0-
    if check == "UPC could not be found":
        print(check)
    else:
        dict_edamam = translate_N2E(check)
        frames.append(dict_edamam)
nutrix_found = pd.concat(frames)
""
# Out:
#   File "C:\Users\Joshua\AppData\Local\Temp/ipykernel_35272/3040992223.py", line 13
#     ""
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
'''
#The dataframe appears to still have some duplicate cereal labels, so we're dropping them
Found = Found.drop_duplicates(subset=['label'],keep='last')

#Add source column and fill with 
Found['Source'] = 'EDAMAM_API'

#Since calling all the UPCs takes a long time, we're saving the 
#dataframe into an excel sheet for quicker loader later on
Found.to_excel("Ed.xlsx", sheet_name='Cereal Data')
'''
# Out:
# '\n#The dataframe appears to still have some duplicate cereal labels, so we\'re dropping them\nFound = Found.drop_duplicates(subset=[\'label\'],keep=\'last\')\n\n#Add source column and fill with \nFound[\'Source\'] = \'EDAMAM_API\'\n\n#Since calling all the UPCs takes a long time, we\'re saving the \n#dataframe into an excel sheet for quicker loader later on\nFound.to_excel("Ed.xlsx", sheet_name=\'Cereal Data\')\n'

# %% [markdown]
# ### 1.2 Cleaning and re-scaling
# Various data sources may contain different variable names, different units, or different serving sizes. Also, missing values can be an issue. Here, you are asked to:
# - Make sure that variable names in all dataframes that you created match.
# - Make sure that all nutritional measurements in all data frames are the same (e.g. per cup or per 100gr).
# - Merge the different data sources.
#
# The final data set should include a column indicating the source of the observation (i.e. is it from the API, entered manually from a certain store, etc.).

# %%
# rename columns
Found = Found.rename(columns={"ENERC_KCAL": "CALORIES",
                              "CHOCDF": "CARB", 
                              "PROCNT": "PROTEIN", 
                              "FE": "IRON", 
                              "CA": "CALCIUM", 
                              "FIBTG": "FIBER",
                              "FAPU": "FAPOLY",
                              "FAMS": "FATMONO"
                             })
Found = Found.drop(columns=['WATER', 'VITK1', 'TOCPHA', 'RIBF', 'VITB12', 'Sugar.alcohol', 'VITC', 'THIA', 'ZN', 'K'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35272/4189621023.py in <module>
#       9                               "FAMS": "FATMONO"
#      10                              })
# ---> 11 Found = Found.drop(columns=['WATER', 'VITK1', 'TOCPHA', 'RIBF', 'VITB12', 'Sugar.alcohol', 'VITC', 'THIA', 'ZN', 'K'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['WATER' 'VITK1' 'TOCPHA' 'RIBF' 'VITB12' 'Sugar.alcohol' 'VITC' 'THIA'\n 'ZN' 'K'] not found in axis"

# %%
#Concat WholeFoods_GiantEagle Data with data from Edamam API
Nutrition_df = pd.concat([Found, WF_GE_DF], axis=0, ignore_index=True)
Nutrition_df

#remove duplicates
Nutrition_df = Nutrition_df.drop_duplicates(subset=['label'],keep='last')

# Save combined data to Excel to read from
Nutrition_df.to_excel("Cereal_Nutrition.xlsx", sheet_name='Cereal Data')

# %%
Cereals_df = pd.read_excel('Cereal_Nutrition.xlsx')
#len(Cereals_df['label'])

# %%
Cereals_df.describe()
# Out:
#        Unnamed: 0    CALORIES         FAT       FASAT  FATRN     FATMONO  \
# count  609.000000  609.000000  606.000000  590.000000  596.0  320.000000
# mean   404.366174  337.780980    2.963560    0.179434    0.0    0.841533
# std    223.906786   79.475219    2.650944    0.676768    0.0    1.306884
# min      0.000000   40.576827    0.000000    0.000000    0.0    0.000000
# 25%    213.000000  345.000000    1.014172    0.000000    0.0    0.000000
# 50%    414.000000  358.691755    2.027827    0.000000    0.0    0.000000
# 75%    603.000000  381.000000    4.990100    0.000000    0.0    1.790000
# max    764.000000  436.000000   15.000000    8.000000    0.0    6.670000
#
#            FAPOLY        CARB       FIBER       SUGAR  SUGAR.added  \
# count  323.000000  609.000000  606.000000  601.000000   165.000000
# mean     0.920939   73.198757    7.270172   10.871023    12.162424
# std      0.803420   19.507452    4.823023    7.631822     6.607612
# min      0.000000    7.000000    0.000000    0.000000     0.000000
# 25%      0.000000   74.075320    3.300000    3.571429     7.000000
# 50%      0.910000   80.000000    7.100000   10.000000    11.000000
# 75%      1.670000   84.379997   10.344828   18.750000    18.299999
# max      2.860000  110.000000   45.725504   32.142857    26.700001
#
#           PROTEIN       CHOLE           NA      CALCIUM          MG  \
# count  609.000000  585.000000   608.000000   493.000000  295.000000
# mean     8.530505    0.058019   392.667647   154.291895   87.495850
# std      3.453061    0.992195   279.289555   242.132545   44.768445
# min      0.000000    0.000000     0.000000     0.000000    0.000000
# 25%      6.670000    0.000000   110.000000     0.000000   56.219170
# 50%      8.330000    0.000000   432.719684    35.273962   80.000000
# 75%     10.344828    0.000000   571.428571   326.000000  114.060822
# max     31.250000   17.636981  1484.151949  3527.396195  323.000000
#
#              IRON            P         NIA          FOLAC  servingSize_gram  \
# count  546.000000   414.000000  434.000000     218.000000        572.000000
# mean    24.274699   252.916276   15.404002    1299.973973         39.340723
# std     13.082001   153.948644   12.036307   12955.916132         11.930692
# min      0.000000     0.000000    0.000000       0.000000          1.000000
# 25%     16.017500   133.000000    9.091000     190.202740         29.000000
# 50%     28.462438   254.815391   15.625000     358.000000         33.000000
# 75%     30.000000   333.000000   17.636981     665.346697         52.000000
# max     63.493132  1129.000000   70.547924  191667.000000         65.000000
#
#        servingSize_cup           upc      VITB6A        VITD
# count       476.000000  5.350000e+02  414.000000  198.000000
# mean          0.901953  9.406952e+10    1.671906    2.315729
# std           0.329494  1.880423e+11    1.352431    2.813532
# min           0.250000  1.600028e+09    0.000000    0.000000
# 25%           0.750000  2.133306e+10    0.938285    0.000000
# 50%           1.000000  4.127004e+10    1.562000    1.742190
# 75%           1.000000  7.078447e+10    1.763698    3.527396
# max           5.500000  8.849124e+11    7.054792    8.818490

# %% [markdown]
# # Dealing withNan Values
# Some of the nutrition columns have NaN values. I'm going to replace those with 0.
# ![Drake Meme NaN Values](WhatsApp-Image-2020-07-01-at-2.09.25-AM.jpg)
# Image Source: https://www.geeksforgeeks.org/replace-nan-values-with-zeros-in-pandas-dataframe/

# %%
#Replace NaN with 0 for Nutrition Columns
cols = ['CALORIES', 'FAT', 'NA', 'CARB', 'FASAT','FATRN', 'FATMONO', 'FAPOLY', 'FIBER', 'SUGAR', 'SUGAR.added', 
        'PROTEIN', 'P', 'IRON', 'CALCIUM', 'MG', 'CHOLE', 'NIA', 'FOLAC', 'VITD', 'VITB6A', 'VITD']
for col in cols:
    Cereals_df[col] = Cereals_df[col].fillna(0)

# %% [markdown]
# ### 1.3 Descriptive statistics
# Create a table with descriptive statistics (Mean, Median, standard deviation, range, number of missing observations, etc.

# %%
Cereals_df.describe()
# Out:
#        Unnamed: 0    CALORIES         FAT       FASAT  FATRN     FATMONO  \
# count  609.000000  609.000000  609.000000  609.000000  609.0  609.000000
# mean   404.366174  337.780980    2.948961    0.173836    0.0    0.442185
# std    223.906786   79.475219    2.652537    0.666841    0.0    1.035850
# min      0.000000   40.576827    0.000000    0.000000    0.0    0.000000
# 25%    213.000000  345.000000    1.000000    0.000000    0.0    0.000000
# 50%    414.000000  358.691755    2.015655    0.000000    0.0    0.000000
# 75%    603.000000  381.000000    4.960401    0.000000    0.0    0.000000
# max    764.000000  436.000000   15.000000    8.000000    0.0    6.670000
#
#            FAPOLY        CARB       FIBER       SUGAR  SUGAR.added  \
# count  609.000000  609.000000  609.000000  609.000000   609.000000
# mean     0.488445   73.198757    7.234358   10.728218     3.295238
# std      0.743941   19.507452    4.838005    7.681984     6.406590
# min      0.000000    7.000000    0.000000    0.000000     0.000000
# 25%      0.000000   74.075320    3.300000    3.570000     0.000000
# 50%      0.000000   80.000000    7.100000   10.000000     0.000000
# 75%      0.910000   84.379997   10.344828   18.750000     2.000000
# max      2.860000  110.000000   45.725504   32.142857    26.700001
#
#           PROTEIN       CHOLE           NA      CALCIUM          MG  \
# count  609.000000  609.000000   609.000000   609.000000  609.000000
# mean     8.530505    0.055733   392.022873   124.902962   42.383047
# std      3.453061    0.972481   279.513047   226.095851   53.705732
# min      0.000000    0.000000     0.000000     0.000000    0.000000
# 25%      6.670000    0.000000   110.000000     0.000000    0.000000
# 50%      8.330000    0.000000   432.106034    20.000000    0.000000
# 75%     10.344828    0.000000   571.428571   312.000000   77.000000
# max     31.250000   17.636981  1484.151949  3527.396195  323.000000
#
#              IRON            P         NIA          FOLAC  servingSize_gram  \
# count  609.000000   609.000000  609.000000     609.000000        572.000000
# mean    21.763523   171.933232   10.977565     465.343721         39.340723
# std     14.427320   173.336527   12.322563    7765.183557         11.930692
# min      0.000000     0.000000    0.000000       0.000000          1.000000
# 25%      3.804078     0.000000    0.000000       0.000000         29.000000
# 50%     28.120001   133.333333    9.300000       0.000000         33.000000
# 75%     30.000000   282.191696   16.666667     261.000000         52.000000
# max     63.493132  1129.000000   70.547924  191667.000000         65.000000
#
#        servingSize_cup           upc      VITB6A        VITD
# count       476.000000  5.350000e+02  609.000000  609.000000
# mean          0.901953  9.406952e+10    1.136567    0.752897
# std           0.329494  1.880423e+11    1.360843    1.934803
# min           0.250000  1.600028e+09    0.000000    0.000000
# 25%           0.750000  2.133306e+10    0.000000    0.000000
# 50%           1.000000  4.127004e+10    0.962000    0.000000
# 75%           1.000000  7.078447e+10    1.653467    0.000000
# max           5.500000  8.849124e+11    7.054792    8.818490

# %% [markdown]
# ## 2 Market Analysis
# ### 2.1 Visualisation
# Create scatter plots of the data. Here you have to try several pairs of characteristics on which it seems like the products are more differentiated. This is a visual exercise but you can support your claims by looking at standard deviations and correlations.

# %%
#making a short list of nutrition facts (you can make your own!)

nutrition_facts = ['CALORIES', 
                   'FAT', 
                   'NA', 
                   'CARB', 
                   'FIBER', 
                   'SUGAR', 
                   'SUGAR.added', 
                   'PROTEIN', 
                   'P', 
                   'IRON', 
                   'CALCIUM', 
                   'MG',
                   'CHOLE',
                   'NIA',
                   'FOLAC',
                   'VITD'
                  ]

# %% [markdown]
# Correlation matrix

# %% [markdown]
# Bellow are a selection of the correlations that will be interesting to look at
# - SUGAR v FAT : 0.097480
# - SUGAR v FIBER: 0.181976
# - SUGAR v PROTEIN: -0.018871
# - FAT v FIBER: 0.217190
# - FAT v PROTEIN: 0.130331
# - PROTEIN v FIBER: 0.447352

# %%
Cereals_df[nutrition_facts].corr()
# Out:
#              CALORIES       FAT        NA      CARB     FIBER     SUGAR  \
# CALORIES     1.000000 -0.009624  0.419633  0.904863  0.174764  0.236083
# FAT         -0.009624  1.000000 -0.188190 -0.267745  0.217190  0.097480
# NA           0.419633 -0.188190  1.000000  0.416390 -0.121775 -0.144370
# CARB         0.904863 -0.267745  0.416390  1.000000  0.214969  0.270215
# FIBER        0.174764  0.217190 -0.121775  0.214969  1.000000  0.181976
# SUGAR        0.236083  0.097480 -0.144370  0.270215  0.181976  1.000000
# SUGAR.added -0.103152  0.077046 -0.284197 -0.083218 -0.023492  0.366986
# PROTEIN      0.468216  0.130331  0.098917  0.325419  0.447352 -0.018871
# P            0.018891  0.268920 -0.090456  0.046866  0.592940  0.241768
# IRON         0.458747 -0.124310  0.338896  0.531767  0.263282  0.421904
# CALCIUM      0.132315  0.097534  0.255289  0.067865  0.070844 -0.125929
# MG           0.184073  0.175411 -0.016703  0.211227  0.647260  0.192721
# CHOLE        0.012870 -0.010087  0.058568  0.018498  0.035165  0.009735
# NIA          0.253534 -0.141238  0.379227  0.339958  0.248523  0.263507
# FOLAC        0.020330 -0.023447 -0.047508  0.035721  0.025113  0.054646
# VITD         0.110204 -0.074663  0.287066  0.143762 -0.000478  0.016230
#
#              SUGAR.added   PROTEIN         P      IRON   CALCIUM        MG  \
# CALORIES       -0.103152  0.468216  0.018891  0.458747  0.132315  0.184073
# FAT             0.077046  0.130331  0.268920 -0.124310  0.097534  0.175411
# NA             -0.284197  0.098917 -0.090456  0.338896  0.255289 -0.016703
# CARB           -0.083218  0.325419  0.046866  0.531767  0.067865  0.211227
# FIBER          -0.023492  0.447352  0.592940  0.263282  0.070844  0.647260
# SUGAR           0.366986 -0.018871  0.241768  0.421904 -0.125929  0.192721
# SUGAR.added     1.000000 -0.092084 -0.026929 -0.056947 -0.151933 -0.069238
# PROTEIN        -0.092084  1.000000  0.286985  0.248693  0.156465  0.350702
# P              -0.026929  0.286985  1.000000  0.378214  0.180798  0.820023
# IRON           -0.056947  0.248693  0.378214  1.000000  0.251696  0.461496
# CALCIUM        -0.151933  0.156465  0.180798  0.251696  1.000000  0.169038
# MG             -0.069238  0.350702  0.820023  0.461496  0.169038  1.000000
# CHOLE          -0.029526  0.001681  0.064465  0.022963  0.096904  0.001719
# NIA            -0.154044  0.143840  0.383074  0.771655  0.202090  0.395985
# FOLAC           0.109452 -0.001905  0.029581  0.040070 -0.016572  0.030138
# VITD           -0.189069 -0.032535  0.099693  0.262298  0.134236  0.128229
#
#                 CHOLE       NIA     FOLAC      VITD
# CALORIES     0.012870  0.253534  0.020330  0.110204
# FAT         -0.010087 -0.141238 -0.023447 -0.074663
# NA           0.058568  0.379227 -0.047508  0.287066
# CARB         0.018498  0.339958  0.035721  0.143762
# FIBER        0.035165  0.248523  0.025113 -0.000478
# SUGAR        0.009735  0.263507  0.054646  0.016230
# SUGAR.added -0.029526 -0.154044  0.109452 -0.189069
# PROTEIN      0.001681  0.143840 -0.001905 -0.032535
# P            0.064465  0.383074  0.029581  0.099693
# IRON         0.022963  0.771655  0.040070  0.262298
# CALCIUM      0.096904  0.202090 -0.016572  0.134236
# MG           0.001719  0.395985  0.030138  0.128229
# CHOLE        1.000000  0.070734  0.001586  0.229802
# NIA          0.070734  1.000000  0.007876  0.272360
# FOLAC        0.001586  0.007876  1.000000  0.004751
# VITD         0.229802  0.272360  0.004751  1.000000

# %%
plt.scatter(Cereals_df['FAT'], Cereals_df['SUGAR'])
plt.title("Fat vs. Sugar")
plt.xlabel("Fat")
plt.ylabel("Sugar")
plt.show()

plt.scatter(Cereals_df['PROTEIN'], Cereals_df['SUGAR'])
plt.title("Protein vs. Sugar")
plt.xlabel("Protein")
plt.ylabel("Sugar")
plt.show()

plt.scatter(Cereals_df['FAT'], Cereals_df['PROTEIN'])
plt.title("Fat vs. Protein")
plt.xlabel("Fat")
plt.ylabel("Protein")
plt.show()

plt.scatter(Cereals_df['FAT'], Cereals_df['FIBER'])
plt.title("Fat vs. Fiber")
plt.xlabel("Fat")
plt.ylabel("Fiber")
plt.show()

plt.scatter(Cereals_df['SUGAR'], Cereals_df['FIBER'])
plt.title("Sugar vs. Fiber")
plt.xlabel("Sugar")
plt.ylabel("Fiber")
plt.show()

plt.scatter(Cereals_df['PROTEIN'], Cereals_df['FIBER'])
plt.title("Protein vs. Fiber")
plt.xlabel("Protein")
plt.ylabel("Fiber")
plt.show()

# %% [markdown]
# I checked the apparent most outlier for fiber and that data appears valid. It is for a cereal for called 'Fiber One'.

# %% [markdown]
# From the correlation matrix Sugar v. Cholesterol looked very uncorrelated, but there are some extreme outliers, so I'm not going to use it.

# %%
plt.scatter(Cereals_df['SUGAR'], Cereals_df['CHOLE'])
plt.title("Sugar vs. Cholesterol")
plt.xlabel("Sugar")
plt.ylabel("Cholesterol")
plt.show()

# %%
fig = plt.figure(figsize=(12,12))
ax = plt.axes(projection ="3d")

ax.scatter( Cereals_df['FAT'], Cereals_df['CARB'],Cereals_df['PROTEIN'])

ax.set_xlabel('FAT')
ax.set_ylabel('CARB')
ax.set_zlabel('PROTEIN')

fig.suptitle('Product differentiation - 3D')
plt.show()

# %% [markdown]
# ### 2.2 K-Means clustering
# Using the K-means clustering technique analyze the degree of product differentiation. Based on descriptive statistics, data availability, and scatter plots, choose pairs of features (i.e., nutrition facts) on which you believe the sellers differentiate themselves. Quantify your answer. You should try different K parameters. Report the goodness of fit (total sum of errors). *Instead of different pairs of features you can focus on the same pair and compare different locations or different supermarkets.*

# %% [markdown]
# ### Choosing k
#
# Using inertia to choose K. The performance of the clustering based on k clusters is often evaluated based on something called _Inertia_ which is defined in the following way:
#
# If after the algorithm converged, the $k$ centroids are $c_1,...,c_k$, then
#
# $$Inertia(k) = \sum_{j=1}^k \sum_{i \in \mathcal{C}_k}(x_i - c_j)^2$$
# is the _Inertia_ measure for $k$.

# %%
features = ['PROTEIN','SUGAR']

#Create new data frame to PROTEIN and SUGAR with
selected_columns = Cereals_df[features]
features_df = selected_columns.copy()

# Trying k=1..12

inertia = []
n_clusters = []
for i in range(1,13):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0).fit(features_df[features])
    inertia.append(kmeans.inertia_)
    n_clusters.append(i)
    
plt.plot(n_clusters,inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.title("Inertia of K-means clustering")
plt.show()
# Out:
# C:\Users\Joshua\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %% [markdown]
# Seeing what the kmeans graphs look like with k=3, k=4 and k=5

# %%
for k in range(3,6):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=0).fit(features_df[features])
    # Note:  K-means++ is a version of K-means algorithm which is more efficient
   
    #scatter plot for the dataset
    plt.scatter(data=Cereals_df, x=features[0], y=features[1],c=kmeans.labels_)
    plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],marker="X", c="r", s=80, label="centroids")
    plt.title(f"Position of {n} cereals in {k} clusters")
    plt.xlabel(features[0])
    plt.ylabel(features[1])
    plt.show()

    print(f"The inertia measure for k={k} is {kmeans.inertia_}")
# Out:
# The inertia measure for k=3 is 9202.753211129117
# The inertia measure for k=4 is 6974.027015544558
# The inertia measure for k=5 is 5177.476617284239

# %% [markdown]
# I personally think the k = 5 has the clearest clustering, although an argument could be made for k = 4 as well.

# %% [markdown]
# ## Now lets look at some more cereal nutrition features
# ### Protein vs Fiber

# %%
features = ['PROTEIN','FIBER']

#Create new data frame to PROTEIN and SUGAR with
selected_columns = Cereals_df[features]
features_df = selected_columns.copy()

# Trying k=1..12

inertia = []
n_clusters = []
for i in range(1,13):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0).fit(features_df[features])
    inertia.append(kmeans.inertia_)
    n_clusters.append(i)
    
plt.plot(n_clusters,inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.title("Inertia of K-means clustering")
plt.show()
# Out:
# C:\Users\Joshua\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
for k in range(3,6):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=0).fit(features_df[features])
    # Note:  K-means++ is a version of K-means algorithm which is more efficient
   
    #scatter plot for the dataset
    plt.scatter(data=Cereals_df, x=features[0], y=features[1],c=kmeans.labels_)
    plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],marker="X", c="r", s=80, label="centroids")
    plt.title(f"Position of {n} cereals in {k} clusters")
    plt.xlabel(features[0])
    plt.ylabel(features[1])
    plt.show()

    print(f"The inertia measure for k={k} is {kmeans.inertia_}")
# Out:
# The inertia measure for k=3 is 8131.8952368911505
# The inertia measure for k=4 is 6393.522652632558
# The inertia measure for k=5 is 4745.063090535173

# %% [markdown]
# ### Fat vs Sugar

# %%
features = ['FAT','SUGAR']

#Create new data frame to PROTEIN and SUGAR with
selected_columns = Cereals_df[features]
features_df = selected_columns.copy()

# Trying k=1..12

inertia = []
n_clusters = []
for i in range(1,13):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0).fit(features_df[features])
    inertia.append(kmeans.inertia_)
    n_clusters.append(i)
    
plt.plot(n_clusters,inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.title("Inertia of K-means clustering")
plt.show()
# Out:
# C:\Users\Joshua\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
for k in range(3,6):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=0).fit(features_df[features])
    # Note:  K-means++ is a version of K-means algorithm which is more efficient
   
    #scatter plot for the dataset
    plt.scatter(data=Cereals_df, x=features[0], y=features[1],c=kmeans.labels_)
    plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],marker="X", c="r", s=80, label="centroids")
    plt.title(f"Position of {n} cereals in {k} clusters")
    plt.xlabel(features[0])
    plt.ylabel(features[1])
    plt.show()

    print(f"The inertia measure for k={k} is {kmeans.inertia_}")
# Out:
# The inertia measure for k=3 is 6389.42169744096
# The inertia measure for k=4 is 4916.53950693782
# The inertia measure for k=5 is 4026.4628382747565

# %% [markdown]
# The axis for fat and sugar are scaled differently. I'm going to rescale them and then see what it looks like.
#
# Rescaling of a variable $x$ is done in the following way:
# $$\frac{x -min(x)}{max(x)-min(x)} .$$

# %%
# Scaling to a unit interval

def  rescaleFeatures(df_in):
    # This function rescale all the columns in dataframe df_in to be
    # between 0 and 1. It returns the scaled dataframe as well as the
    # lists of minimum and the maximum (so we can rescale back)

    df_out = df_in # first, we make a copy of the original df
    mins = df_out.min() # a list of minimums for all columns in df_in
    maxs = df_out.max() # a list of maximums for all columns in df_in
    for i in range(len(df_out.columns)):
        df_out.iloc[:,i] = (df_out.iloc[:,i] - mins[i])/(maxs[i]-mins[i])
    
    return df_out,m,M

# %% [markdown]
# ## 3 Conclusions
# Summarize your findings and draw conclusions from them. What can you recommend to cereal producers on the market? Do you find this market to be saturated? Here, I leave it to you to analyze your findings as you see fit. Given all the effort you have put, This section should be as very important.
